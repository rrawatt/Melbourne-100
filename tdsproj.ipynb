# %%
import requests
import pandas as pd
import time

# %%
GITHUB_TOKEN = ''
HEADERS = {'Authorization': f'token {GITHUB_TOKEN}'}

# %%
def check_rate_limit():
    url = "https://api.github.com/rate_limit"
    response = requests.get(url, headers=HEADERS)
    if response.status_code == 200:
        data = response.json()
        remaining = data['rate']['remaining']
        reset_time = data['rate']['reset']
        return remaining, reset_time
    return 0, 0

# %%
def handle_rate_limit():
    remaining, reset_time = check_rate_limit()
    if remaining == 0:
        wait_time = reset_time - time.time()
        print(f"Rate limit exceeded. Waiting for {wait_time/60:.2f} minutes.")
        time.sleep(wait_time + 10)  # Add a little buffer to avoid hitting it immediately again
    else:
        print(f"Remaining requests: {remaining}")

# %%
def clean_company_name(company):
    if company:
        company = company.strip()  
        if company.startswith('@'):
            company = company[1:] 
        return company.upper() 
    return None

# %%
def get_users_in_city(city, min_followers):
    users = []
    page = 1
    while True:
        url = f"https://api.github.com/search/users?q=location:{city}+followers:>{min_followers}&per_page=100&page={page}"
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            break
        data = response.json()
        users.extend(data['items'])
        if len(data['items']) == 0:
            break
        page += 1
        time.sleep(1)  
    return users

# %%
def get_user_details(username):
    url = f"https://api.github.com/users/{username}"
    response = requests.get(url, headers=HEADERS)
    if response.status_code == 200:
        return response.json()
    return None

# %%
def get_user_repos(username):
    repos = []
    page = 1
    while True:
        url = f"https://api.github.com/users/{username}/repos?per_page=100&page={page}&sort=pushed"
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            break
        data = response.json()
        repos.extend(data)
        if len(data) == 0:
            break
        page += 1
        time.sleep(1)
    return repos[:500]

# %%
def main():
    city = "Melbourne"
    min_followers = 100

    users = get_users_in_city(city, min_followers)
    user_data = []
    repo_data = []

    for user in users:
        handle_rate_limit()
        user_details = get_user_details(user['login'])
        if user_details:
            user_info = {
                'login': user_details['login'],
                'name': user_details['name'],
                'company': clean_company_name(user_details['company']),
                'location': user_details['location'],
                'email': user_details['email'],
                'hireable': user_details['hireable'],
                'bio': user_details['bio'],
                'public_repos': user_details['public_repos'],
                'followers': user_details['followers'],
                'following': user_details['following'],
                'created_at': user_details['created_at']
            }
            user_data.append(user_info)
            handle_rate_limit()

            # Fetch repositories for the user
            repos = get_user_repos(user['login'])
            for repo in repos:
                repo_info = {
                    'login': user_details['login'],
                    'full_name': repo['full_name'],
                    'created_at': repo['created_at'],
                    'stargazers_count': repo['stargazers_count'],
                    'watchers_count': repo['watchers_count'],
                    'language': repo['language'],
                    'has_projects': repo['has_projects'],
                    'has_wiki': repo['has_wiki'],
                    'license_name': repo['license']['name'] if repo['license'] else None
                }
                repo_data.append(repo_info)

    df_users = pd.DataFrame(user_data)
    df_users.to_csv('users.csv', index=False)

    df_repos = pd.DataFrame(repo_data)
    df_repos.to_csv('repositories.csv', index=False)

    print("Data saved to 'users.csv' and 'repositories.csv'")

# %%
if __name__ == "__main__":
    main()
# Out:
# Remaining requests: 4876
# Remaining requests: 4875
# Remaining requests: 4873
# Remaining requests: 4872
# Remaining requests: 4870
# Remaining requests: 4869
# Remaining requests: 4864
# Remaining requests: 4863
# Remaining requests: 4856
# Remaining requests: 4855
# Remaining requests: 4853
# Remaining requests: 4852
# Remaining requests: 4846
# Remaining requests: 4845
# Remaining requests: 4841
# Remaining requests: 4840
# Remaining requests: 4838
# Remaining requests: 4837
# Remaining requests: 4835
# Remaining requests: 4834
# Remaining requests: 4830
# Remaining requests: 4829
# Remaining requests: 4826
# Remaining requests: 4825
# Remaining requests: 4823
# Remaining requests: 4822
# Remaining requests: 4820
# Remaining requests: 4819
# Remaining requests: 4816
# Remaining requests: 4815
# Remaining requests: 4812
# Remaining requests: 4811
# Remaining requests: 4807
# Remaining requests: 4806
# Remaining requests: 4804
# Remaining requests: 4803
# Remaining requests: 4800
# Remaining requests: 4799
# Remaining requests: 4794
# Remaining requests: 4793
# Remaining requests: 4791
# Remaining requests: 4790
# Remaining requests: 4787
# Remaining requests: 4786
# Remaining requests: 4784
# Remaining requests: 4783
# Remaining requests: 4778
# Remaining requests: 4777
# Remaining requests: 4774
# Remaining requests: 4773
# Remaining requests: 4771
# Remaining requests: 4770
# Remaining requests: 4767
# Remaining requests: 4766
# Remaining requests: 4763
# Remaining requests: 4762
# Remaining requests: 4757
# Remaining requests: 4756
# Remaining requests: 4754
# Remaining requests: 4753
# Remaining requests: 4751
# Remaining requests: 4750
# Remaining requests: 4747
# Remaining requests: 4746
# Remaining requests: 4741
# Remaining requests: 4740
# Remaining requests: 4738
# Remaining requests: 4737
# Remaining requests: 4735
# Remaining requests: 4734
# Remaining requests: 4732
# Remaining requests: 4731
# Remaining requests: 4728
# Remaining requests: 4727
# Remaining requests: 4725
# Remaining requests: 4724
# Remaining requests: 4722
# Remaining requests: 4721
# Remaining requests: 4718
# Remaining requests: 4717
# Remaining requests: 4714
# Remaining requests: 4713
# Remaining requests: 4711
# Remaining requests: 4710
# Remaining requests: 4707
# Remaining requests: 4706
# Remaining requests: 4702
# Remaining requests: 4701
# Remaining requests: 4699
# Remaining requests: 4698
# Remaining requests: 4697
# Remaining requests: 4696
# Remaining requests: 4694
# Remaining requests: 4693
# Remaining requests: 4691
# Remaining requests: 4690
# Remaining requests: 4688
# Remaining requests: 4687
# Remaining requests: 4684
# Remaining requests: 4683
# Remaining requests: 4680
# Remaining requests: 4679
# Remaining requests: 4677
# Remaining requests: 4676
# Remaining requests: 4674
# Remaining requests: 4673
# Remaining requests: 4669
# Remaining requests: 4668
# Remaining requests: 4664
# Remaining requests: 4663
# Remaining requests: 4660
# Remaining requests: 4659
# Remaining requests: 4657
# Remaining requests: 4656
# Remaining requests: 4653
# Remaining requests: 4652
# Remaining requests: 4650
# Remaining requests: 4649
# Remaining requests: 4646
# Remaining requests: 4645
# Remaining requests: 4641
# Remaining requests: 4640
# Remaining requests: 4637
# Remaining requests: 4636
# Remaining requests: 4634
# Remaining requests: 4633
# Remaining requests: 4630
# Remaining requests: 4629
# Remaining requests: 4627
# Remaining requests: 4626
# Remaining requests: 4624
# Remaining requests: 4623
# Remaining requests: 4620
# Remaining requests: 4619
# Remaining requests: 4617
# Remaining requests: 4616
# Remaining requests: 4613
# Remaining requests: 4612
# Remaining requests: 4610
# Remaining requests: 4609
# Remaining requests: 4604
# Remaining requests: 4603
# Remaining requests: 4599
# Remaining requests: 4598
# Remaining requests: 4596
# Remaining requests: 4595
# Remaining requests: 4593
# Remaining requests: 4592
# Remaining requests: 4589
# Remaining requests: 4588
# Remaining requests: 4585
# Remaining requests: 4584
# Remaining requests: 4581
# Remaining requests: 4580
# Remaining requests: 4578
# Remaining requests: 4577
# Remaining requests: 4575
# Remaining requests: 4574
# Remaining requests: 4572
# Remaining requests: 4571
# Remaining requests: 4568
# Remaining requests: 4567
# Remaining requests: 4565
# Remaining requests: 4564
# Remaining requests: 4561
# Remaining requests: 4560
# Remaining requests: 4555
# Remaining requests: 4554
# Remaining requests: 4552
# Remaining requests: 4551
# Remaining requests: 4549
# Remaining requests: 4548
# Remaining requests: 4546
# Remaining requests: 4545
# Remaining requests: 4543
# Remaining requests: 4542
# Remaining requests: 4536
# Remaining requests: 4535
# Remaining requests: 4530
# Remaining requests: 4529
# Remaining requests: 4525
# Remaining requests: 4524
# Remaining requests: 4520
# Remaining requests: 4519
# Remaining requests: 4516
# Remaining requests: 4515
# Remaining requests: 4512
# Remaining requests: 4511
# Remaining requests: 4509
# Remaining requests: 4508
# Remaining requests: 4506
# Remaining requests: 4505
# Remaining requests: 4503
# Remaining requests: 4502
# Remaining requests: 4500
# Remaining requests: 4499
# Remaining requests: 4497
# Remaining requests: 4496
# Remaining requests: 4494
# Remaining requests: 4493
# Remaining requests: 4490
# Remaining requests: 4489
# Remaining requests: 4487
# Remaining requests: 4486
# Remaining requests: 4483
# Remaining requests: 4482
# Remaining requests: 4480
# Remaining requests: 4479
# Remaining requests: 4477
# Remaining requests: 4476
# Remaining requests: 4473
# Remaining requests: 4472
# Remaining requests: 4470
# Remaining requests: 4469
# Remaining requests: 4467
# Remaining requests: 4466
# Remaining requests: 4463
# Remaining requests: 4462
# Remaining requests: 4460
# Remaining requests: 4459
# Remaining requests: 4457
# Remaining requests: 4456
# Remaining requests: 4454
# Remaining requests: 4453
# Remaining requests: 4451
# Remaining requests: 4450
# Remaining requests: 4448
# Remaining requests: 4447
# Remaining requests: 4445
# Remaining requests: 4444
# Remaining requests: 4442
# Remaining requests: 4441
# Remaining requests: 4439
# Remaining requests: 4438
# Remaining requests: 4436
# Remaining requests: 4435
# Remaining requests: 4433
# Remaining requests: 4432
# Remaining requests: 4430
# Remaining requests: 4429
# Remaining requests: 4426
# Remaining requests: 4425
# Remaining requests: 4423
# Remaining requests: 4422
# Remaining requests: 4420
# Remaining requests: 4419
# Remaining requests: 4417
# Remaining requests: 4416
# Remaining requests: 4414
# Remaining requests: 4413
# Remaining requests: 4411
# Remaining requests: 4410
# Remaining requests: 4408
# Remaining requests: 4407
# Remaining requests: 4404
# Remaining requests: 4403
# Remaining requests: 4401
# Remaining requests: 4400
# Remaining requests: 4398
# Remaining requests: 4397
# Remaining requests: 4395
# Remaining requests: 4394
# Remaining requests: 4392
# Remaining requests: 4391
# Remaining requests: 4389
# Remaining requests: 4388
# Remaining requests: 4386
# Remaining requests: 4385
# Remaining requests: 4383
# Remaining requests: 4382
# Remaining requests: 4380
# Remaining requests: 4379
# Remaining requests: 4376
# Remaining requests: 4375
# Remaining requests: 4369
# Remaining requests: 4368
# Remaining requests: 4366
# Remaining requests: 4365
# Remaining requests: 4363
# Remaining requests: 4362
# Remaining requests: 4360
# Remaining requests: 4359
# Remaining requests: 4357
# Remaining requests: 4356
# Remaining requests: 4353
# Remaining requests: 4352
# Remaining requests: 4350
# Remaining requests: 4349
# Remaining requests: 4346
# Remaining requests: 4345
# Remaining requests: 4343
# Remaining requests: 4342
# Remaining requests: 4339
# Remaining requests: 4338
# Remaining requests: 4336
# Remaining requests: 4335
# Remaining requests: 4332
# Remaining requests: 4331
# Remaining requests: 4329
# Remaining requests: 4328
# Remaining requests: 4326
# Remaining requests: 4325
# Remaining requests: 4323
# Remaining requests: 4322
# Remaining requests: 4319
# Remaining requests: 4318
# Remaining requests: 4316
# Remaining requests: 4315
# Remaining requests: 4313
# Remaining requests: 4312
# Remaining requests: 4310
# Remaining requests: 4309
# Remaining requests: 4307
# Remaining requests: 4306
# Remaining requests: 4303
# Remaining requests: 4302
# Remaining requests: 4300
# Remaining requests: 4299
# Remaining requests: 4293
# Remaining requests: 4292
# Remaining requests: 4290
# Remaining requests: 4289
# Remaining requests: 4286
# Remaining requests: 4285
# Remaining requests: 4281
# Remaining requests: 4280
# Remaining requests: 4278
# Remaining requests: 4277
# Remaining requests: 4275
# Remaining requests: 4274
# Remaining requests: 4272
# Remaining requests: 4271
# Remaining requests: 4266
# Remaining requests: 4265
# Remaining requests: 4263
# Remaining requests: 4262
# Remaining requests: 4260
# Remaining requests: 4259
# Remaining requests: 4257
# Remaining requests: 4256
# Remaining requests: 4254
# Remaining requests: 4253
# Remaining requests: 4251
# Remaining requests: 4250
# Remaining requests: 4247
# Remaining requests: 4246
# Remaining requests: 4244
# Remaining requests: 4243
# Remaining requests: 4241
# Remaining requests: 4240
# Remaining requests: 4238
# Remaining requests: 4237
# Remaining requests: 4236
# Remaining requests: 4235
# Remaining requests: 4233
# Remaining requests: 4232
# Remaining requests: 4230
# Remaining requests: 4229
# Remaining requests: 4227
# Remaining requests: 4226
# Remaining requests: 4225
# Remaining requests: 4224
# Remaining requests: 4222
# Remaining requests: 4221
# Remaining requests: 4218
# Remaining requests: 4217
# Remaining requests: 4215
# Remaining requests: 4214
# Remaining requests: 4212
# Remaining requests: 4211
# Remaining requests: 4209
# Remaining requests: 4208
# Remaining requests: 4205
# Remaining requests: 4204
# Remaining requests: 4202
# Remaining requests: 4201
# Remaining requests: 4199
# Remaining requests: 4198
# Remaining requests: 4196
# Remaining requests: 4195
# Remaining requests: 4192
# Remaining requests: 4191
# Remaining requests: 4189
# Remaining requests: 4188
# Remaining requests: 4184
# Remaining requests: 4183
# Remaining requests: 4181
# Remaining requests: 4180
# Remaining requests: 4178
# Remaining requests: 4177
# Remaining requests: 4175
# Remaining requests: 4174
# Remaining requests: 4172
# Remaining requests: 4171
# Remaining requests: 4169
# Remaining requests: 4168
# Remaining requests: 4166
# Remaining requests: 4165
# Remaining requests: 4163
# Remaining requests: 4162
# Remaining requests: 4160
# Remaining requests: 4159
# Remaining requests: 4157
# Remaining requests: 4156
# Remaining requests: 4154
# Remaining requests: 4153
# Remaining requests: 4149
# Remaining requests: 4148
# Remaining requests: 4146
# Remaining requests: 4145
# Remaining requests: 4143
# Remaining requests: 4142
# Remaining requests: 4138
# Remaining requests: 4137
# Remaining requests: 4135
# Remaining requests: 4134
# Remaining requests: 4132
# Remaining requests: 4131
# Remaining requests: 4129
# Remaining requests: 4128
# Remaining requests: 4126
# Remaining requests: 4125
# Remaining requests: 4123
# Remaining requests: 4122
# Remaining requests: 4120
# Remaining requests: 4119
# Remaining requests: 4117
# Remaining requests: 4116
# Remaining requests: 4114
# Remaining requests: 4113
# Remaining requests: 4111
# Remaining requests: 4110
# Remaining requests: 4108
# Remaining requests: 4107
# Remaining requests: 4105
# Remaining requests: 4104
# Remaining requests: 4101
# Remaining requests: 4100
# Remaining requests: 4098
# Remaining requests: 4097
# Remaining requests: 4095
# Remaining requests: 4094
# Remaining requests: 4092
# Remaining requests: 4091
# Remaining requests: 4089
# Remaining requests: 4088
# Remaining requests: 4086
# Remaining requests: 4085
# Remaining requests: 4083
# Remaining requests: 4082
# Remaining requests: 4080
# Remaining requests: 4079
# Remaining requests: 4077
# Remaining requests: 4076
# Remaining requests: 4074
# Remaining requests: 4073
# Remaining requests: 4071
# Remaining requests: 4070
# Remaining requests: 4068
# Remaining requests: 4067
# Remaining requests: 4065
# Remaining requests: 4064
# Remaining requests: 4062
# Remaining requests: 4061
# Remaining requests: 4059
# Remaining requests: 4058
# Remaining requests: 4056
# Remaining requests: 4055
# Remaining requests: 4053
# Remaining requests: 4052
# Remaining requests: 4049
# Remaining requests: 4048
# Remaining requests: 4046
# Remaining requests: 4045
# Remaining requests: 4043
# Remaining requests: 4042
# Remaining requests: 4999
# Remaining requests: 4998
# Remaining requests: 4996
# Remaining requests: 4995
# Remaining requests: 4991
# Remaining requests: 4990
# Remaining requests: 4988
# Remaining requests: 4987
# Remaining requests: 4985
# Remaining requests: 4984
# Remaining requests: 4982
# Remaining requests: 4981
# Remaining requests: 4979
# Remaining requests: 4978
# Remaining requests: 4976
# Remaining requests: 4975
# Remaining requests: 4973
# Remaining requests: 4972
# Remaining requests: 4970
# Remaining requests: 4969
# Remaining requests: 4967
# Remaining requests: 4966
# Remaining requests: 4964
# Remaining requests: 4963
# Remaining requests: 4961
# Remaining requests: 4960
# Remaining requests: 4958
# Remaining requests: 4957
# Remaining requests: 4955
# Remaining requests: 4954
# Remaining requests: 4952
# Remaining requests: 4951
# Remaining requests: 4949
# Remaining requests: 4948
# Remaining requests: 4945
# Remaining requests: 4944
# Remaining requests: 4942
# Remaining requests: 4941
# Remaining requests: 4939
# Remaining requests: 4938
# Remaining requests: 4936
# Remaining requests: 4935
# Remaining requests: 4931
# Remaining requests: 4930
# Remaining requests: 4928
# Remaining requests: 4927
# Remaining requests: 4925
# Remaining requests: 4924
# Remaining requests: 4922
# Remaining requests: 4921
# Remaining requests: 4919
# Remaining requests: 4918
# Remaining requests: 4916
# Remaining requests: 4915
# Remaining requests: 4911
# Remaining requests: 4910
# Remaining requests: 4908
# Remaining requests: 4907
# Remaining requests: 4905
# Remaining requests: 4904
# Remaining requests: 4902
# Remaining requests: 4901
# Remaining requests: 4899
# Remaining requests: 4898
# Remaining requests: 4896
# Remaining requests: 4895
# Remaining requests: 4892
# Remaining requests: 4891
# Remaining requests: 4889
# Remaining requests: 4888
# Remaining requests: 4886
# Remaining requests: 4885
# Remaining requests: 4883
# Remaining requests: 4882
# Remaining requests: 4880
# Remaining requests: 4879
# Remaining requests: 4877
# Remaining requests: 4876
# Remaining requests: 4874
# Remaining requests: 4873
# Remaining requests: 4871
# Remaining requests: 4870
# Remaining requests: 4867
# Remaining requests: 4866
# Remaining requests: 4863
# Remaining requests: 4862
# Remaining requests: 4860
# Remaining requests: 4859
# Remaining requests: 4857
# Remaining requests: 4856
# Remaining requests: 4854
# Remaining requests: 4853
# Remaining requests: 4851
# Remaining requests: 4850
# Remaining requests: 4848
# Remaining requests: 4847
# Remaining requests: 4845
# Remaining requests: 4844
# Remaining requests: 4841
# Remaining requests: 4840
# Remaining requests: 4838
# Remaining requests: 4837
# Remaining requests: 4835
# Remaining requests: 4834
# Remaining requests: 4831
# Remaining requests: 4830
# Remaining requests: 4826
# Remaining requests: 4825
# Remaining requests: 4823
# Remaining requests: 4822
# Remaining requests: 4820
# Remaining requests: 4819
# Remaining requests: 4817
# Remaining requests: 4816
# Remaining requests: 4813
# Remaining requests: 4812
# Remaining requests: 4810
# Remaining requests: 4809
# Remaining requests: 4807
# Remaining requests: 4806
# Remaining requests: 4804
# Remaining requests: 4803
# Remaining requests: 4801
# Remaining requests: 4800
# Remaining requests: 4797
# Remaining requests: 4796
# Remaining requests: 4793
# Remaining requests: 4792
# Remaining requests: 4790
# Remaining requests: 4789
# Remaining requests: 4787
# Remaining requests: 4786
# Remaining requests: 4784
# Remaining requests: 4783
# Remaining requests: 4780
# Remaining requests: 4779
# Remaining requests: 4777
# Remaining requests: 4776
# Remaining requests: 4774
# Remaining requests: 4773
# Remaining requests: 4772
# Remaining requests: 4771
# Remaining requests: 4769
# Remaining requests: 4768
# Remaining requests: 4766
# Remaining requests: 4765
# Remaining requests: 4763
# Remaining requests: 4762
# Remaining requests: 4760
# Remaining requests: 4759
# Remaining requests: 4757
# Remaining requests: 4756
# Remaining requests: 4754
# Remaining requests: 4753
# Remaining requests: 4751
# Remaining requests: 4750
# Remaining requests: 4748
# Remaining requests: 4747
# Remaining requests: 4745
# Remaining requests: 4744
# Remaining requests: 4742
# Remaining requests: 4741
# Remaining requests: 4739
# Remaining requests: 4738
# Remaining requests: 4736
# Remaining requests: 4735
# Remaining requests: 4732
# Remaining requests: 4731
# Remaining requests: 4720
# Remaining requests: 4719
# Remaining requests: 4717
# Remaining requests: 4716
# Remaining requests: 4714
# Remaining requests: 4713
# Remaining requests: 4711
# Remaining requests: 4710
# Remaining requests: 4708
# Remaining requests: 4707
# Remaining requests: 4704
# Remaining requests: 4703
# Remaining requests: 4701
# Remaining requests: 4700
# Remaining requests: 4697
# Remaining requests: 4696
# Remaining requests: 4693
# Remaining requests: 4692
# Data saved to 'users.csv' and 'repositories.csv'
